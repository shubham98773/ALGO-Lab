# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham98773/ALGO-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    predecessors = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')
        predecessors[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    return distances, predecessors

# %%
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10, 'E': 7},
    'C': {'A': 2, 'B': 5, 'D': 3, 'F': 8},
    'D': {'B': 10, 'C': 3, 'E': 6},
    'E': {'B': 7, 'D': 6, 'F': 1},
    'F': {'C': 8, 'E': 1}
}

def print_shortest_path(distances, predecessors, start_node, target_node):
    path = []
    current = target_node
    while current is not None:
        path.insert(0, current)
        current = predecessors[current]

    if path[0] == start_node:
        print(f"Shortest path from {start_node} to {target_node}: {" -> ".join(path)} (Total distance: {distances[target_node]})")
    else:
        print(f"No path from {start_node} to {target_node} found.")

print("--- Testing with predefined graph ---")
source_nodes_to_test = ['A', 'B', 'C']
target_nodes = list(graph.keys())

for start_node in source_nodes_to_test:
    print(f"\nFrom source node: {start_node}")
    distances, predecessors = dijkstra(graph, start_node)
    for target_node in target_nodes:
        if start_node == target_node:
            print(f"Shortest path from {start_node} to {target_node}: {start_node} (Total distance: 0)")
        else:
            print_shortest_path(distances, predecessors, start_node, target_node)
# Out:
# --- Testing with predefined graph ---
#
# From source node: A
# Shortest path from A to A: A (Total distance: 0)
# Shortest path from A to B: A -> B (Total distance: 4)
# Shortest path from A to C: A -> C (Total distance: 2)
# Shortest path from A to D: A -> C -> D (Total distance: 5)
# Shortest path from A to E: A -> B -> E (Total distance: 11)
# Shortest path from A to F: A -> C -> F (Total distance: 10)
#
# From source node: B
# Shortest path from B to A: B -> A (Total distance: 4)
# Shortest path from B to B: B (Total distance: 0)
# Shortest path from B to C: B -> C (Total distance: 5)
# Shortest path from B to D: B -> C -> D (Total distance: 8)
# Shortest path from B to E: B -> E (Total distance: 7)
# Shortest path from B to F: B -> E -> F (Total distance: 8)
#
# From source node: C
# Shortest path from C to A: C -> A (Total distance: 2)
# Shortest path from C to B: C -> B (Total distance: 5)
# Shortest path from C to C: C (Total distance: 0)
# Shortest path from C to D: C -> D (Total distance: 3)
# Shortest path from C to E: C -> D -> E (Total distance: 9)
# Shortest path from C to F: C -> F (Total distance: 8)

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
